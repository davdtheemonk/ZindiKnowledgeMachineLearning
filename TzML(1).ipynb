# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

dftrain = pd.read_csv(r'/content/drive/MyDrive/tanzaniaML/Train.csv')
dftest = pd.read_csv(r'/content/drive/MyDrive/tanzaniaML/Test.csv')
dfvar =  pd.read_csv(r'/content/drive/MyDrive/tanzaniaML/VariableDefinitions.csv')
dfsub = pd.read_csv(r'/content/drive/MyDrive/tanzaniaML/SampleSubmission.csv')

# %%
dftrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     4809 non-null   object
#  1   country                4809 non-null   object
#  2   age_group              4809 non-null   object
#  3   travel_with            3695 non-null   object
#  4   total_female           4806 non-null   float64
#  5   total_male             4804 non-null   float64
#  6   purpose                4809 non-null   object
#  7   main_activity          4809 non-null   object
#  8   info_source            4809 non-null   object
#  9   tour_arrangement       4809 non-null   object
#  10  package_transport_int  4809 non-null   object
#  11  package_accomodation   4809 non-null   object
#  12  package_food           4809 non-null   object
#  13  package_transport_tz   4809 non-null   object
# ...

# %%
dftest.info()
print(dftest.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     1601 non-null   object
#  1   country                1601 non-null   object
#  2   age_group              1601 non-null   object
#  3   travel_with            1274 non-null   object
#  4   total_female           1600 non-null   float64
#  5   total_male             1599 non-null   float64
#  6   purpose                1601 non-null   object
#  7   main_activity          1601 non-null   object
#  8   info_source            1601 non-null   object
#  9   tour_arrangement       1601 non-null   object
#  10  package_transport_int  1601 non-null   object
#  11  package_accomodation   1601 non-null   object
#  12  package_food           1601 non-null   object
#  13  package_transport_tz   1601 non-null   object
# ...

# %%
dftrain.describe()
# Out:
#        total_female   total_male  night_mainland  night_zanzibar    total_cost
# count   4806.000000  4804.000000     4809.000000     4809.000000  4.809000e+03
# mean       0.926758     1.009575        8.488043        2.304429  8.114389e+06
# std        1.288242     1.138865       10.427624        4.227080  1.222490e+07
# min        0.000000     0.000000        0.000000        0.000000  4.900000e+04
# 25%        0.000000     1.000000        3.000000        0.000000  8.121750e+05
# 50%        1.000000     1.000000        6.000000        0.000000  3.397875e+06
# 75%        1.000000     1.000000       11.000000        4.000000  9.945000e+06
# max       49.000000    44.000000      145.000000       61.000000  9.953288e+07

# %%
dftrain.keys()
# Out:
# Index(['ID', 'country', 'age_group', 'travel_with', 'total_female',
#        'total_male', 'purpose', 'main_activity', 'info_source',
#        'tour_arrangement', 'package_transport_int', 'package_accomodation',
#        'package_food', 'package_transport_tz', 'package_sightseeing',
#        'package_guided_tour', 'package_insurance', 'night_mainland',
#        'night_zanzibar', 'payment_mode', 'first_trip_tz', 'most_impressing',
#        'total_cost'],
#       dtype='object')

# %%
dftrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4809 entries, 0 to 4808
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     4809 non-null   object
#  1   country                4809 non-null   object
#  2   age_group              4809 non-null   object
#  3   travel_with            3695 non-null   object
#  4   total_female           4806 non-null   float64
#  5   total_male             4804 non-null   float64
#  6   purpose                4809 non-null   object
#  7   main_activity          4809 non-null   object
#  8   info_source            4809 non-null   object
#  9   tour_arrangement       4809 non-null   object
#  10  package_transport_int  4809 non-null   object
#  11  package_accomodation   4809 non-null   object
#  12  package_food           4809 non-null   object
#  13  package_transport_tz   4809 non-null   object
# ...

# %%
dftrain.fillna(dftrain.mean(), inplace=True)
dftrain.isna().sum()
# Out:
# ID                          0
# country                     0
# age_group                   0
# travel_with              1114
# total_female                0
# total_male                  0
# purpose                     0
# main_activity               0
# info_source                 0
# tour_arrangement            0
# package_transport_int       0
# package_accomodation        0
# package_food                0
# package_transport_tz        0
# package_sightseeing         0
# package_guided_tour         0
# package_insurance           0
# night_mainland              0
# night_zanzibar              0
# payment_mode                0
# first_trip_tz               0
# most_impressing           313
# total_cost                  0
# dtype: int64

# %%
dftrain.fillna(dftrain.mode().iloc[0],inplace=True)

# %%
dftest.fillna(dftest.mean(), inplace=True)
dftest.fillna(dftest.mode().iloc[0],inplace=True)

# %%
dftrain
# Out:
#              ID  ...  total_cost
# 0        tour_0  ...    674602.5
# 1       tour_10  ...   3214906.5
# 2     tour_1000  ...   3315000.0
# 3     tour_1002  ...   7790250.0
# 4     tour_1004  ...   1657500.0
# ...         ...  ...         ...
# 4804   tour_993  ...   3315000.0
# 4805   tour_994  ...  10690875.0
# 4806   tour_995  ...   2246636.7
# 4807   tour_997  ...   1160250.0
# 4808   tour_999  ...  13260000.0
#
# [4809 rows x 23 columns]

# %%
dftrain
# Out:
#              ID  ...  total_cost
# 0        tour_0  ...    674602.5
# 1       tour_10  ...   3214906.5
# 2     tour_1000  ...   3315000.0
# 3     tour_1002  ...   7790250.0
# 4     tour_1004  ...   1657500.0
# ...         ...  ...         ...
# 4804   tour_993  ...   3315000.0
# 4805   tour_994  ...  10690875.0
# 4806   tour_995  ...   2246636.7
# 4807   tour_997  ...   1160250.0
# 4808   tour_999  ...  13260000.0
#
# [4809 rows x 23 columns]

# %%
y = dftrain['total_cost']
X  = dftrain.drop(['total_cost','ID'],axis=1)

# %%
X.shape
# Out:
# (4809, 21)

# %%
y.shape
# Out:
# (4809,)

# %%
dftest.shape
# Out:
# (1601, 22)

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=0)

# %%
from sklearn.preprocessing import LabelEncoder
Enc = LabelEncoder()
Categorical_colms = ["country","age_group","travel_with","purpose","main_activity","info_source","tour_arrangement","package_transport_int","package_accomodation","package_food","package_transport_tz","package_sightseeing","package_guided_tour","package_insurance","payment_mode","first_trip_tz","most_impressing"]
for colm in Categorical_colms:
  X_train[colm] = pd.get_dummies(X_train[colm]) 
  X_test[colm] = pd.get_dummies(X_test[colm])

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3606 entries, 1596 to 2732
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   country                3606 non-null   uint8
#  1   age_group              3606 non-null   uint8
#  2   travel_with            3606 non-null   uint8
#  3   total_female           3606 non-null   float64
#  4   total_male             3606 non-null   float64
#  5   purpose                3606 non-null   uint8
#  6   main_activity          3606 non-null   uint8
#  7   info_source            3606 non-null   uint8
#  8   tour_arrangement       3606 non-null   uint8
#  9   package_transport_int  3606 non-null   uint8
#  10  package_accomodation   3606 non-null   uint8
#  11  package_food           3606 non-null   uint8
#  12  package_transport_tz   3606 non-null   uint8
#  13  package_sightseeing    3606 non-null   uint8
# ...

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1203 entries, 825 to 4631
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   country                1203 non-null   int64
#  1   age_group              1203 non-null   int64
#  2   travel_with            1203 non-null   int64
#  3   total_female           1203 non-null   float64
#  4   total_male             1203 non-null   float64
#  5   purpose                1203 non-null   int64
#  6   main_activity          1203 non-null   int64
#  7   info_source            1203 non-null   int64
#  8   tour_arrangement       1203 non-null   int64
#  9   package_transport_int  1203 non-null   int64
#  10  package_accomodation   1203 non-null   int64
#  11  package_food           1203 non-null   int64
#  12  package_transport_tz   1203 non-null   int64
#  13  package_sightseeing    1203 non-null   int64
# ...

# %%
X_train
# Out:
#       country  age_group  ...  first_trip_tz  most_impressing
# 1596        0          0  ...              1                1
# 2217        0          0  ...              0                1
# 2967        0          0  ...              0                0
# 2868        0          0  ...              0                0
# 4321        0          0  ...              1                0
# ...       ...        ...  ...            ...              ...
# 1033        0          0  ...              0                0
# 3264        0          0  ...              0                0
# 1653        0          0  ...              1                0
# 2607        0          0  ...              0                0
# 2732        0          0  ...              0                0
#
# [3606 rows x 21 columns]

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(model.coef_)
print(model.intercept_)
print(model.score(X_test,y_test))
# Out:
# [-6381597.31254035 -1255069.71171699 -2447355.23969082  1304343.69883201
#   1428682.0978849    -69358.53333839 -1266729.58834712  -542201.62175615
#  -1330497.35426067 -3843498.1625011  -1045844.79126653 -1508206.60635938
#  -1896505.85058711 -2288152.77796863  -382249.31984698   -10380.92376252
#     95616.98858608   181333.06014416 -2693016.88327407  -463589.54783176
#    165379.59602103]
# 16397225.532404013
# 0.2626974791513894

# %%
dftest.shape
# Out:
# (1601, 22)

# %%
dftest = dftest.drop('ID',axis=1)
dftest
# Out:
#                        country  ...                       most_impressing
# 0                    AUSTRALIA  ...                              Wildlife
# 1                 SOUTH AFRICA  ...  Wonderful Country, Landscape, Nature
# 2                      GERMANY  ...                           No comments
# 3                       CANADA  ...                       Friendly People
# 4               UNITED KINGDOM  ...                       Friendly People
# ...                        ...  ...                                   ...
# 1596  UNITED STATES OF AMERICA  ...                       Friendly People
# 1597                     ITALY  ...                              Wildlife
# 1598                   FINLAND  ...                           No comments
# 1599              SOUTH AFRICA  ...                              Wildlife
# 1600              SOUTH AFRICA  ...                       Friendly People
#
# [1601 rows x 21 columns]

# %%
for colm in Categorical_colms:
  dftest[colm]  = pd.get_dummies(dftest[colm])

# %%
yprob = model.predict(dftest)

# %%
list(yprob)
# Out:
# [18102783.108161185,
#  14043514.332593817,
#  6247364.963258892,
#  3477822.7891007233,
#  16903445.485090293,
#  4509004.524364699,
#  7404056.540366501,
#  -241688.26426322944,
#  -1718148.593828436,
#  7377336.146456828,
#  15231246.116145423,
#  19517235.912350707,
#  22730765.521471355,
#  4739547.435571436,
#  6192754.633005131,
#  9589296.968265891,
#  6300405.3050726205,
#  12851708.43075534,
#  8640918.65543734,
#  16927059.864271626,
#  43727.47128576413,
#  4311773.650413616,
#  9407123.183004001,
#  571433.6979432777,
#  953901.6522875968,
#  7874960.025436476,
#  1443685.0709223356,
#  -408099.0163969472,
#  4032772.790426856,
#  17740969.48917315,
#  8557632.914065376,
#  14293555.423899338,
#  425833.09716298245,
#  20697315.973533485,
#  15728192.314643674,
#  2896478.0219716616,
#  1226526.6026776582,
#  4218302.306250576,
#  6360266.995479582,
#  2118579.8097127043,
#  1382482.0100780204,
#  5893427.427796055,
#  342341.4971930571,
#  -455170.6104920618,
# ...

# %%
yprob.shape
# Out:
# (1601,)

# %%
dfsub.shape
# Out:
# (1601, 2)

# %%
dftest.shape
# Out:
# (1177, 21)

# %%
dftest1 = pd.read_csv(r'/content/drive/MyDrive/tanzaniaML/Test.csv')

# %%
dftest1.shape
# Out:
# (1601, 22)

# %%
preds_df_final = dftest1[['ID']]
preds_df_final['total_cost']=yprob
preds_df_final.to_csv('final454.csv', index=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
preds_df_final
# Out:
#              ID    total_cost
# 0        tour_1  1.810278e+07
# 1      tour_100  1.404351e+07
# 2     tour_1001  6.247365e+06
# 3     tour_1006  3.477823e+06
# 4     tour_1009  1.690345e+07
# ...         ...           ...
# 1596   tour_988  1.222716e+04
# 1597   tour_990  1.898882e+07
# 1598   tour_992  4.117000e+05
# 1599   tour_996 -2.205312e+06
# 1600   tour_998  5.899117e+06
#
# [1601 rows x 2 columns]
